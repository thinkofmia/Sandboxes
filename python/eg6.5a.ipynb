# %% [markdown]
# # Chapter 6, Example 5a

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
import tensorflow.keras.datasets.mnist as mnist

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
batch_size = 128
num_classes = 10
no_epochs = 25

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(625, activation='relu'),
    Dropout(rate=0.2),
    Dense(100, activation='relu'),
    Dropout(rate=0.2),
    Dense(10, activation='softmax')
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=no_epochs,
                    verbose=2,
                    use_multiprocessing=True,
                    validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 - 33s - loss: 1.2708 - accuracy: 0.6516 - val_loss: 0.5541 - val_accuracy: 0.8675
# Epoch 2/20
# 60000/60000 - 26s - loss: 0.5682 - accuracy: 0.8386 - val_loss: 0.3770 - val_accuracy: 0.9015
# Epoch 3/20
# 60000/60000 - 28s - loss: 0.4480 - accuracy: 0.8710 - val_loss: 0.3183 - val_accuracy: 0.9123
# Epoch 4/20
# 60000/60000 - 19s - loss: 0.3869 - accuracy: 0.8873 - val_loss: 0.2849 - val_accuracy: 0.9214
# Epoch 5/20
# 60000/60000 - 10s - loss: 0.3528 - accuracy: 0.8980 - val_loss: 0.2636 - val_accuracy: 0.9265
# Epoch 6/20
# 60000/60000 - 9s - loss: 0.3265 - accuracy: 0.9051 - val_loss: 0.2444 - val_accuracy: 0.9315
# Epoch 7/20
# 60000/60000 - 10s - loss: 0.3043 - accuracy: 0.9105 - val_loss: 0.2302 - val_accuracy: 0.9339
# Epoch 8/20
# 60000/60000 - 9s - loss: 0.2887 - accuracy: 0.9159 - val_loss: 0.2179 - val_accuracy: 0.9370
# Epoch 9/20
# 60000/60000 - 9s - loss: 0.2731 - accuracy: 0.9200 - val_loss: 0.2077 - val_accuracy: 0.9395
# Epoch 10/20
# 60000/60000 - 9s - loss: 0.2568 - accuracy: 0.9253 - val_loss: 0.1981 - val_accuracy: 0.9425
# Epoch 11/20
# 60000/60000 - 10s - loss: 0.2477 - accuracy: 0.9274 - val_loss: 0.1890 - val_accuracy: 0.9437
# Epoch 12/20
# 60000/60000 - 9s - loss: 0.2352 - accuracy: 0.9317 - val_loss: 0.1816 - val_accuracy: 0.9462
# Epoch 13/20
# 60000/60000 - 9s - loss: 0.2273 - accuracy: 0.9342 - val_loss: 0.1745 - val_accuracy: 0.9484
# Epoch 14/20
# 60000/60000 - 10s - loss: 0.2187 - accuracy: 0.9362 - val_loss: 0.1691 - val_accuracy: 0.9496
# Epoch 15/20
# 60000/60000 - 9s - loss: 0.2117 - accuracy: 0.9384 - val_loss: 0.1637 - val_accuracy: 0.9516
# Epoch 16/20
# 60000/60000 - 10s - loss: 0.2026 - accuracy: 0.9409 - val_loss: 0.1577 - val_accuracy: 0.9528
# Epoch 17/20
# 60000/60000 - 14s - loss: 0.1963 - accuracy: 0.9432 - val_loss: 0.1533 - val_accuracy: 0.9549
# Epoch 18/20
# 60000/60000 - 28s - loss: 0.1909 - accuracy: 0.9445 - val_loss: 0.1494 - val_accuracy: 0.9562
# Epoch 19/20
# 60000/60000 - 27s - loss: 0.1849 - accuracy: 0.9467 - val_loss: 0.1441 - val_accuracy: 0.9580
# Epoch 20/20
# 60000/60000 - 26s - loss: 0.1796 - accuracy: 0.9476 - val_loss: 0.1403 - val_accuracy: 0.9592

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
